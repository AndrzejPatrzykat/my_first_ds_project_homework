# %%
# Zadanie 1
temperatury = [22.5, 23.0, 21.5, 24.0, 23.5, 22.0, 23.0]
print(temperatury)
print(f" Temperatura pierwszego dnia: {temperatury[0]}")
print(f" Temperatura ostatniego dnia: {temperatury[-1]}")
print(f" Temperatura z trzech środkowych dni: {temperatury[2:5]}")
# Out:
# [22.5, 23.0, 21.5, 24.0, 23.5, 22.0, 23.0]
#  Temperatura pierwszego dnia: 22.5
#  Temperatura ostatniego dnia: 23.0
#  Temperatura z trzech środkowych dni: [21.5, 24.0, 23.5]

# %%
# Zadanie 2
results = []

lista_lista = [0.75, 0.82, 0.79, 0.85, 0.88]
for pozycja in lista_lista:
    results.append(pozycja)

print(results)
print(f"Długość listy: len(results)")
print(f"Średnia wartość: {sum(results) / len(results):.2f}")
print(f"Maksymalna wartość: {max(results)}")
print(f"Minimalna wartość: {min(results)}")
# Out:
# [0.75, 0.82, 0.79, 0.85, 0.88]
# Długość listy: len(results)
# Średnia wartość: 0.82
# Maksymalna wartość: 0.88
# Minimalna wartość: 0.75

# %%
# Zadanie 3
wyniki = [0.78, 0.92, 0.85, 0.88, 0.81, 0.95, 0.79]
wyniki_posortowane = sorted(wyniki, reverse = True)
print(wyniki_posortowane[:3])
# Out:
# [0.95, 0.92, 0.88]

# %%
# Zadanie 4
raw_col = " Customer ID "
nowy_string = raw_col.strip().lower().replace(' ', '_')
print(nowy_string)
# Out:
# customer_id

# %%
# Zadanie 5
linia = "Alice,28,Data Scientist,75000"
lista_szczegolow = linia.split(",")
print(f"{lista_szczegolow[0]} ma {lista_szczegolow[1]} lat, pracuje jako {lista_szczegolow[2]} i zarabia ${lista_szczegolow[3]}.")
# Out:
# Alice ma 28 lat, pracuje jako Data Scientist i zarabia $75000.

# %%
# Zadanie 6
model_name = "XGBoost"
accuracy = 0.8934
training_time = 45.67

print(f"Model: {model_name} \n   Accuracy: {accuracy:.2%} \n   Training time: {training_time}s")
# Out:
# Model: XGBoost
#    Accuracy: 89.34%
#    Training time: 45.67s

# %%
# Zadanie 7
predykcje = ['spam', 'ham', 'spam', 'spam', 'ham', 'ham', 'spam']
wystapienia_spam = predykcje.count('spam')
wystapienia_ham = predykcje.count('ham')
print(f"Spam: {wystapienia_spam}, Ham: {wystapienia_ham}")
# Out:
# Spam: 4, Ham: 3

# %%
# Zadanie 8
filename = "model_results_2024_Q3.csv"
czesci = filename.split("_")
rok = czesci[2]
kwartal = czesci[3].split(".")[0]
print(f"Rok: {czesci[2]}, Kwartał: {kwartal}")

wynik = filename.endswith("csv")
print(f"Czy plik csv: {wynik}")
# Out:
# Rok: 2024, Kwartał: Q3
# Czy plik csv: True

# %%
# Zadanie 9
cm = [
[80, 10], # TN, FP
[5, 45] # FN, TP
]
print(cm)

tn = cm[0][0]
tp = cm[1][1]
fn = cm[1][0]
fp = cm[0][1]

print(tn)
print(tp)
print(fn)
print(fp)

accuracy = (tp + tn) / (tp +tn + fp + fn)
precision = tp / (tp + fp)
recall = tp / (tp + fn)

print(f"Accuracy: {accuracy:.2%} Precision: {precision:.2%} Recall: {recall:.2%}")
# Out:
# [[80, 10], [5, 45]]
# 80
# 45
# 5
# 10
# Accuracy: 89.29% Precision: 81.82% Recall: 90.00%

# %%
# Zadanie 10
modele = ['LogisticRegression', 'RandomForest', 'XGBoost', 'SVM']

modele_join = ", ".join(lista_modeli) # ze spacją kacztken
print(modele_join)
string_sql = f"SELECT model FROM ({modele_join})"
print(string_sql)

#co to jest w tym from ???bo mi to tabeli nie przypomina

modele_split = modele_join.split(", ") # ze spacja musze podzielic
czy_takie_same = modele == modele_split

print(czy_takie_same)
print(modele)
print(modele_split)
# Out:
# LogisticRegression, RandomForest, XGBoost, SVM
# SELECT model FROM (LogisticRegression, RandomForest, XGBoost, SVM)
# True
# ['LogisticRegression', 'RandomForest', 'XGBoost', 'SVM']
# ['LogisticRegression', 'RandomForest', 'XGBoost', 'SVM']

# %%
# Zadanie 11
logi = "2024-01-15 10:23:45 ERROR Training failed due to OOM"
podzielony = logi.split(" ", 3)

# [2024-01-15 10:23:45] ERROR: Training failed due to OOM
print(f"[{podzielony[0]} {podzielony[1]}] {podzielony[2]}: {podzielony[3]}")

poziomy = ['INFO','WARNING', 'ERROR', 'DEBUG']
poziom_znany = podzielony[2] in poziomy
print(f"Czy poziom znany? {poziom_znany}")
# Out:
# [2024-01-15 10:23:45] ERROR: Training failed due to OOM
# Czy poziom znany? True

# %%
# Zadanie 12
tabela = "customers"
kolumny = ['id', 'name', 'email', 'city']
warunek = "city = 'New York'"

print(f"SELECT {', '.join(kolumny)} FROM {tabela} WHERE {warunek}")
# Out:
# SELECT id, name, email, city FROM customers WHERE city = 'New York'

# %%
# Zadanie 13
m1 = ['LogisticRegression', 0.78]
m2 = ['RandomForest', 0.92]
m3 = ['SVM', 0.85]
m4 = ['XGBoost', 0.95]

wszystkie = [m1, m2, m3, m4]
wszystkie_accuracy = [m1[1], m2[1], m3[1], m4[1]]
wszystkie_accuracy.sort(reverse=True)
maks = max(wszystkie_accuracy)
mini = min(wszystkie_accuracy)

print(f"Posortowana lista: {wszystkie_accuracy}")
print(f"Top3 z listy: {wszystkie_accuracy[:3]}")
print(f"Najlepsze accruracy: {maks}")
print(f"Najgorsze accruracy: {mini}")
# Out:
# Posortowana lista: [0.95, 0.92, 0.85, 0.78]
# Top3 z listy: [0.95, 0.92, 0.85]
# Najlepsze accruracy: 0.95
# Najgorsze accruracy: 0.78

# %%
# Zadanie 14
sciezka_pliku = "/data/processed/2024/experiment_42_v3.csv"

podzial = sciezka_pliku.split('/')


nazwa_pliku = podzial[-1]
katalog = '/'.join(podzial[:4])
nazwa_pliku_bez_rozszerzenia = podzial[-1].split('.')[0]
rozszerzenie = sciezka_pliku.split('_')[-1][-4:]
rok = podzial[3]

print(f"{'Nazwa pliku:':<30} {nazwa_pliku}")
print(f"{'Katalog':<30} {katalog}")
print(f"{'Nazwa pliku bez rozszerzenia':<30} {nazwa_pliku_bez_rozszerzenia}")
print(f"{'Rozszerzenie':<30} {rozszerzenie}")
print(f"{'Rok':<30} {rok}")
# Out:
# Nazwa pliku:                   experiment_42_v3.csv
# Katalog                        /data/processed/2024
# Nazwa pliku bez rozszerzenia   experiment_42_v3
# Rozszerzenie                   .csv
# Rok                            2024

# %%
# Zadanie 15
kat_a = " Electronics "
kat_b = "ELECTRONICS"
kat_a_znor = kat_a.strip().lower()
kat_b_znor = kat_b.strip().lower()

print(f"Przed normalizacją:")
print(kat_a)
print(kat_b)

print(f"\nPo normalizacji:")
print(kat_a_znor)
print(kat_b_znor)

wynik = kat_a_znor == kat_b_znor
print(f"\nCzy takie same ? {wynik}")
# Out:
# Przed normalizacją:
#  Electronics
# ELECTRONICS
#
# Po normalizacji:
# electronics
# electronics
#
# Czy takie same ? True

# %%
# Zadanie 16
e1 = ["Exp_01", 0.85, 1.23]
e2 = ["Exp_02", 0.89, 4.56]
e3 = ["Exp_03", 0.87, 7.89]

print('='*44)
print(f"{'Experiment':<15}{'Accuracy':>15}{'Time (s)':>14}")
print(f"{'='*44}")
print(f"{e1[0]:<15}{e1[1]:>14.2%}{e1[2]:>14.2f}")
print(f"{e2[0]:<15}{e2[1]:>14.2%}{e2[2]:>14.2f}")
print(f"{e3[0]:<15}{e3[1]:>14.2%}{e3[2]:>14.2f}")
print(f"{'='*44}")
# Out:
# ...
# Experiment            Accuracy      Time (s)
# ...
# Exp_01                 85.00%          1.23
# Exp_02                 89.00%          4.56
# Exp_03                 87.00%          7.89
# ...

# %%
# Zadanie 17
pole_imie = " Alice "
pole_wiek = " 28 "
pole_email = " alice@EXAMPLE.com "

pole_imie_clear = pole_imie.strip()
pole_wiek_clear = pole_wiek.strip()
pole_email_clear = pole_email.strip().lower()

czy_imie_ok = pole_imie_clear.isalpha()
czy_wiek_ok = pole_wiek_clear.isdigit()
czy_email_ok = '@' in pole_email_clear

wszystko_ok = czy_imie_ok and czy_wiek_ok and czy_email_ok

print(pole_imie_clear)
print(pole_wiek_clear)
print(pole_email_clear)
print('-'*20) 
print(f"Wszystkie pola Okay? {wszystko_ok}")
# Out:
# Alice
# 28
# alice@example.com
# --------------------
# Wszystkie pola Okay? True

# %%
# Zadanie 18
e1 = ["Exp_01", 0.85, 1.23]
e2 = ["Exp_02", 0.89, 4.56]
e3 = ["Exp_03", 0.87, 7.89]
# Out:
# ['# Raport', '| Experiment | Accuracy | Time |', '|------------|----------|------|', '| Exp_01 | 85.00% | 1.23s |', '| Exp_02 | 89.00% | 4.56s |', '| Exp_03 | 87.00% | 7.89s |']
