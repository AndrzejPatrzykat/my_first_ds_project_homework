# %%
# Zadanie 1
# C:\Users\Andrzej>mkdir my_first_ds_projects

# C:\Users\Andrzej>cd my_first_ds_project

# C:\Users\Andrzej\my_first_ds_project>git init
# Initialized empty Git repository in C:/Users/Andrzej/my_first_ds_project/.git/

# C:\Users\Andrzej\my_first_ds_project>echo "# Tutaj bedzie opis projektu" > README.md

# C:\Users\Andrzej\my_first_ds_project>git add README.md

# C:\Users\Andrzej\my_first_ds_project>git commit -m "Pierwszy commit: Add README.md"
# [master (root-commit) 1afcaf9] Pierwszy commit: Add README.md
#  1 file changed, 1 insertion(+)
#  create mode 100644 README.md

# C:\Users\Andrzej\my_first_ds_project>git status
# On branch master
# nothing to commit, working tree clean

# C:\Users\Andrzej\my_first_ds_project>git log --oneline
# 335342c (HEAD -> master) Dodaj .gitigonre do projektu DataScience
# 1afcaf9 Pierwszy commit: Add README.md

# %%
# Zadanie 2
# C:\Users\Andrzej\my_first_ds_project>echo *.csv > .gitignore

# C:\Users\Andrzej\my_first_ds_project>echo data/ >> .gitignore

# C:\Users\Andrzej\my_first_ds_project>echo models/ >> .gitignore

# C:\Users\Andrzej\my_first_ds_project>echo __pycache__/ >> .gitignore

# C:\Users\Andrzej\my_first_ds_project>echo .ipynb_checkpoints/ >>  .gitignore

# C:\Users\Andrzej\my_first_ds_project>git add .gitingonre
# fatal: pathspec '.gitingonre' did not match any files

# C:\Users\Andrzej\my_first_ds_project>git add .gitignore

# C:\Users\Andrzej\my_first_ds_project>git commit -m "Dodaj .gitigonre do projektu DataScience"
# [master 335342c] Dodaj .gitigonre do projektu DataScience
#  1 file changed, 5 insertions(+)
#  create mode 100644 .gitignore

# C:\Users\Andrzej\my_first_ds_project>echo "test data" > test.csv

# C:\Users\Andrzej\my_first_ds_project>git status
# On branch master
# nothing to commit, working tree clean

niby mam get ignore a trafił mi do pliku jak to działa???

# %%
# # Zadanie 3
# C:\Users\Andrzej\my_first_ds_project>git log
# commit 2a4bd70da49e3df226635095f33272ef1af4d94a (HEAD -> master)
# Author: Andrzej <andrzej_patrzykat@wp.pl>
# Date:   Sat Aug 15 16:41:04 2026 +0200

#     Dodanie folderu smieci

# commit abb35a4ead3ab0f7728ae562ac9a9984f1985720
# Author: Andrzej <andrzej_patrzykat@wp.pl>
# Date:   Sat Aug 15 16:39:23 2026 +0200

#     Dodanie folderu model

# commit 7d295dd37b9322715b164159046b22ea34236a3d
# Author: Andrzej <andrzej_patrzykat@wp.pl>
# Date:   Sat Aug 15 16:32:09 2026 +0200

#     Dodanie folderu notebooks

# commit 992d915f9306312ca2d867c64ddfaea1b96441f9
# Author: Andrzej <andrzej_patrzykat@wp.pl>
# Date:   Sat Aug 15 16:30:44 2026 +0200

#     Druga linijka została dodana

# commit 335342cb6e6dd8e77f6eecf0e87df7528ea9f92a
# Author: Andrzej <andrzej_patrzykat@wp.pl>
# Date:   Thu Aug 13 00:07:43 2026 +0200

#     Dodaj .gitigonre do projektu DataScience

# commit 1afcaf9c4ec7b56959ff59d7c2ecf0e97577696a
# Author: Andrzej <andrzej_patrzykat@wp.pl>
# Date:   Thu Aug 13 00:00:06 2026 +0200

#     Pierwszy commit: Add README.md

# C:\Users\Andrzej\my_first_ds_project>git show 992d915f9306312ca2d867c64ddfaea1b96441f9
# commit 992d915f9306312ca2d867c64ddfaea1b96441f9
# Author: Andrzej <andrzej_patrzykat@wp.pl>
# Date:   Sat Aug 15 16:30:44 2026 +0200

#     Druga linijka została dodana

# diff --git a/README.md b/README.md
# index ba19638..2ad1577 100644
# --- a/README.md
# +++ b/README.md
# @@ -1 +1,2 @@
#  "# Tutaj bedzie opis projektu"
# +"# Druga linijka tekstu w tym pliku"

# C:\Users\Andrzej\my_first_ds_project>

# %%
# Zadanie 4 
# C:\Users\Andrzej\my_first_ds_project>git branch
# * master

# C:\Users\Andrzej\my_first_ds_project>git branch feature-data-loading

# C:\Users\Andrzej\my_first_ds_project>git branch feature-preprocessing

# C:\Users\Andrzej\my_first_ds_project>git branch
#   feature-data-loading
#   feature-preprocessing
# * master

# C:\Users\Andrzej\my_first_ds_project>git checkout feature-data-loading
# Switched to branch 'feature-data-loading'

# C:\Users\Andrzej\my_first_ds_project>git branch
# * feature-data-loading
#   feature-preprocessing
#   master

# C:\Users\Andrzej\my_first_ds_project>echo "# Nowy plik w tym folderze" > load_data.py

# C:\Users\Andrzej\my_first_ds_project>git branch
# * feature-data-loading
#   feature-preprocessing
#   master

# C:\Users\Andrzej\my_first_ds_project>git checkout master
# Switched to branch 'master'

# C:\Users\Andrzej\my_first_ds_project>git checkout feature-data-loading
# Switched to branch 'feature-data-loading'

# C:\Users\Andrzej\my_first_ds_project>git checkout master
# Switched to branch 'master'

# C:\Users\Andrzej\my_first_ds_project>git checkout feataire-data-loading
# error: pathspec 'feataire-data-loading' did not match any file(s) known to git

# C:\Users\Andrzej\my_first_ds_project>git checkout feature-data-loading
# Switched to branch 'feature-data-loading'

# C:\Users\Andrzej\my_first_ds_project>git add load_data.py

# C:\Users\Andrzej\my_first_ds_project>git commit -m "Dodanie pliku py"
# [feature-data-loading cad8f6c] Dodanie pliku py
#  1 file changed, 1 insertion(+)
#  create mode 100644 load_data.py

# C:\Users\Andrzej\my_first_ds_project>git checkout master
# Switched to branch 'master'

# C:\Users\Andrzej\my_first_ds_project>git checkout feature-data-loading
# Switched to branch 'feature-data-loading'

# C:\Users\Andrzej\my_first_ds_project>

# %%
# Zadanie 5
# C:\Users\Andrzej\my_first_ds_project>git checkout master
# Switched to branch 'master'

# C:\Users\Andrzej\my_first_ds_project>git checkout feature-data-loading
# Switched to branch 'feature-data-loading'

# C:\Users\Andrzej\my_first_ds_project>git brancb
# git: 'brancb' is not a git command. See 'git --help'.

# The most similar command is
#         branch

# C:\Users\Andrzej\my_first_ds_project>git branch
# * feature-data-loading
#   feature-preprocessing
#   master

# C:\Users\Andrzej\my_first_ds_project>git checkout master
# Switched to branch 'master'

# C:\Users\Andrzej\my_first_ds_project>git merge feature-data-loading
# Updating 2a4bd70..cad8f6c
# Fast-forward
#  load_data.py | 1 +
#  1 file changed, 1 insertion(+)
#  create mode 100644 load_data.py

# C:\Users\Andrzej\my_first_ds_project>git branch -d feature-data-loading
# Deleted branch feature-data-loading (was cad8f6c).

# C:\Users\Andrzej\my_first_ds_project>

# %%
# Zadanie 6
# C:\Users\Andrzej>git clone https://github.com/AndrzejPatrzykat/ds-learning.git
# Cloning into 'ds-learning'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# C:\Users\Andrzej>cd ds_learning
# System nie może odnaleźć określonej ścieżki.

# C:\Users\Andrzej>cd ds-learning

# C:\Users\Andrzej\ds-learning>echo "# Moje notatki z kursu Data Science" > notatki.md

# C:\Users\Andrzej\ds-learning>git add notataki.md
# fatal: pathspec 'notataki.md' did not match any files

# C:\Users\Andrzej\ds-learning>git add notatki.md

# C:\Users\Andrzej\ds-learning>git commit -m "Dodanie pliku notatki.md"
# [main d244dab] Dodanie pliku notatki.md
#  1 file changed, 1 insertion(+)
#  create mode 100644 notatki.md

# C:\Users\Andrzej\ds-learning>git push
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 4 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 328 bytes | 65.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# To https://github.com/AndrzejPatrzykat/ds-learning.git
#    b741987..d244dab  main -> main

# %%
# Zadanie 7
# C:\Users\Andrzej>cd my_first_ds_project

# C:\Users\Andrzej\my_first_ds_project>
# C:\Users\Andrzej\my_first_ds_project>git branch
#   feature-preprocessing
# * master

# C:\Users\Andrzej\my_first_ds_project>git add .

# C:\Users\Andrzej\my_first_ds_project>git commit -m"Commitujemy wsz
# On branch master
# nothing to commit, working tree clean

# C:\Users\Andrzej\my_first_ds_project>git status
# On branch master
# nothing to commit, working tree clean

# C:\Users\Andrzej\my_first_ds_project>git restore --staged .

# C:\Users\Andrzej\my_first_ds_project>git remote origin https://github.com/AndrzejPatrzykat/my_first_ds_project.git
# error: unknown subcommand: `origin'
# usage: git remote [-v | --verbose]
#    or: git remote add [-t <branch>] [-m <master>] [-f] [--tags | --no-tags] [--mirror=<fetch|push>] <name> <url>
#    or: git remote rename [--[no-]progress] <old> <new>
#    or: git remote remove <name>
#    or: git remote set-head <name> (-a | --auto | -d | --delete | <branch>)
#    or: git remote [-v | --verbose] show [-n] <name>
#    or: git remote prune [-n | --dry-run] <name>
#    or: git remote [-v | --verbose] update [-p | --prune] [(<group> | <remote>)...]
#    or: git remote set-branches [--add] <name> <branch>...
#    or: git remote get-url [--push] [--all] <name>
#    or: git remote set-url [--push] <name> <newurl> [<oldurl>]
#    or: git remote set-url --add <name> <newurl>
#    or: git remote set-url --delete <name> <url>

#     -v, --[no-]verbose    be verbose; must be placed before a subcommand


# C:\Users\Andrzej\my_first_ds_project>git remote add origin https://github.com/AndrzejPatrzykat/my_first_ds_project.git

# C:\Users\Andrzej\my_first_ds_project>git push -u origin master
# Enumerating objects: 24, done.
# Counting objects: 100% (24/24), done.
# Delta compression using up to 4 threads
# Compressing objects: 100% (16/16), done.
# Writing objects: 100% (24/24), 2.05 KiB | 150.00 KiB/s, done.
# Total 24 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# remote: Resolving deltas: 100% (4/4), done.
# To https://github.com/AndrzejPatrzykat/my_first_ds_project.git
#  * [new branch]      master -> master
# branch 'master' set up to track 'origin/master'.

# C:\Users\Andrzej\my_first_ds_project>git pull
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 1.02 KiB | 54.00 KiB/s, done.
# From https://github.com/AndrzejPatrzykat/my_first_ds_project
#    cad8f6c..4f025b9  master     -> origin/master
# Updating cad8f6c..4f025b9
# Fast-forward
#  README.md | 1 +
#  1 file changed, 1 insertion(+)

# C:\Users\Andrzej\my_first_ds_project>git log --oneline
# 4f025b9 (HEAD -> master, origin/master, origin/HEAD) Add third line to project description in README
# cad8f6c Dodanie pliku py
# 2a4bd70 (feature-preprocessing) Dodanie folderu smieci
# abb35a4 Dodanie folderu model
# 7d295dd Dodanie folderu notebooks
# 992d915 Druga linijka została dodana
# 335342c Dodaj .gitigonre do projektu DataScience
# 1afcaf9 Pierwszy commit: Add README.md

# C:\Users\Andrzej\my_first_ds_project>
