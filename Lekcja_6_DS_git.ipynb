# %%
# Zadaanie 1

student = {
    'imie': 'Kamil',
    'nazwisko': 'Nowak',
    'wiek': 22,
    'kierunek': 'Informatyka'
}

student['email'] = 'kamil.nowak@edu.pl'
student['wiek'] = 23
print(f"Student: {student['imie']} {student['nazwisko']} ({student['wiek']} lata), kierunek: {student['kierunek']}, email: {student['email']}.")

lista_kluczy = list(student.keys())
print(lista_kluczy)

lista_wartosci = list(student.values())
print(lista_wartosci)
# Out:
# Student: Kamil Nowak (23 lata), kierunek: Informatyka, email: kamil.nowak@edu.pl .
# ['imie', 'nazwisko', 'wiek', 'kierunek', 'email']
# ['Kamil', 'Nowak', 23, 'Informatyka', 'kamil.nowak@edu.pl']

# %%
# Zadanie 2
konfig = {
    'lr': 0.01, 
    'epochs': 100, 
    'optimizer': 'adam'
}

wartosc_lr = konfig.get('lr')
print(wartosc_lr)
wartosc_momentum = konfig.get('momentum')
print(wartosc_momentum)
wartosc_momentum_1 = konfig.get('momentum', 0.9)
print(wartosc_momentum_1)

batch_as_klucz = 'batch_size' in konfig
print(batch_as_klucz)
# Out:
# 0.01
# None
# 0.9
# False

# %%
# Zadanie 3
metryki = dict(accuracy = 0.94, precision = 0.91, recall = 0.89, f1_score = 0.90)
print(metryki)

maks = max(metryki.values())
mini = min(metryki.values())
srednia = sum(metryki.values()) / len(metryki.values())
klucze_posortowane = (sorted(metryki.keys()))
wartosci_posortowane = (sorted(metryki.values()))

print(maks)
print(mini) 
print(f"{srednia:.3f}")
print(klucze_posortowane) 
print(wartosci_posortowane)
# Out:
# {'accuracy': 0.94, 'precision': 0.91, 'recall': 0.89, 'f1_score': 0.9}
# 0.94
# 0.89
# 0.910
# ['accuracy', 'f1_score', 'precision', 'recall']
# [0.89, 0.9, 0.91, 0.94]

# %%
# Zadanke 4
jezyki = ['Python', 'R', 'SQL', 'Python', 'Julia', 'R', 'Python', 'Scala', 'SQL']
unikalne = set(jezyki)
unikalne_liczba = len(unikalne)
unikalne.update(['Go', "Rust"])
python = 'Python' in unikalne
fortran = 'Fortran' in unikalne
julia = 'Julia' in unikalne
unikalne.discard('Scala')

print(unikalne)
print(unikalne_liczba)
print(python)
print(fortran)
print(julia)
print(unikalne)
print(len(unikalne))
# Out:
# {'Go', 'R', 'SQL', 'Julia', 'Rust', 'Python'}
# 5
# True
# False
# True
# {'Go', 'R', 'SQL', 'Julia', 'Rust', 'Python'}
# 6

# %%
# Zadanie 5
grupa_a = {'python', 'pandas', 'numpy', 'sql', 'tableau'}
grupa_b = {'python', 'r', 'sql', 'ggplot2', 'dplyr'}

suma = grupa_a | grupa_b
print(suma)
suma_metoda = grupa_a.union(grupa_b)
print(suma_metoda)

print('_'*75)
iloczyn = grupa_a & grupa_b
print(iloczyn)
iloczyn_metoda = grupa_a.intersection(grupa_b)
print(iloczyn_metoda)

print('_'*75)
roznica = grupa_a - grupa_b
print(roznica)
roznica_metoda = grupa_a.difference(grupa_b)
print(roznica_metoda)

print('_'*75)
roznica_sym = grupa_a ^ grupa_b
print(roznica_sym)
roznica_sym_metoda = grupa_a.symmetric_difference(grupa_b)
print(roznica_sym_metoda)

print('_'*75)
czy_rozloczne = grupa_a.isdisjoint(grupa_b)
print(czy_rozloczne)
# Out:
# {'python', 'sql', 'dplyr', 'pandas', 'r', 'numpy', 'tableau', 'ggplot2'}
# {'python', 'sql', 'dplyr', 'pandas', 'r', 'numpy', 'tableau', 'ggplot2'}
# ___________________________________________________________________________
# {'python', 'sql'}
# {'python', 'sql'}
# ___________________________________________________________________________
# {'tableau', 'pandas', 'numpy'}
# {'tableau', 'pandas', 'numpy'}
# ___________________________________________________________________________
# {'r', 'numpy', 'tableau', 'dplyr', 'pandas', 'ggplot2'}
# {'r', 'numpy', 'tableau', 'dplyr', 'pandas', 'ggplot2'}
# ___________________________________________________________________________
# False

# %%
# ZAdanie 6
wymiary = (1920, 1080)
szerokosc, wysokosc = wymiary
print(f"Rozdzielczość: {szerokosc}x{wysokosc}")

samotny = (42,)
print(type(samotny))

# samotny[0] = 100 krotka jest niemutowalna TypeError

nowa_krotka = samotny + (100,200)
print(nowa_krotka)
# Out:
# Rozdzielczość: 1920x1080
# <class 'tuple'>
# (42, 100, 200)

# %%
# Zadanie 7
pracownik = ('Julia', 'Wiśniewska', 28, 'Data Analyst', 8500.0)
imie, nazwisko, wiek, stanowisko, pensja = pracownik
print(f"{imie} {nazwisko} ({wiek}) - {stanowisko}, pensja: {pensja:.2f} zł .")
imie, *reszta = pracownik
print(imie)
print(reszta)
# Out:
# Julia Wiśniewska (28) - Data Analyst, pensja: 8500.00 zł .
# Julia
# ['Wiśniewska', 28, 'Data Analyst', 8500.0]

# %%
# Zadanie 8
sprzedaz = {
(2024, 'Q1'): 120_000,
(2024, 'Q2'): 140_000,
(2024, 'Q3'): 135_000,
(2024, 'Q4'): 160_000
}
print(f"{sprzedaz[(2024, 'Q2')]:,}")
sprzedaz[(2025, 'Q1')] = 130_000
print(sprzedaz)

maks = max(sprzedaz.values())
print(maks)

mini = min(sprzedaz.values())
print(mini)

suma = sum(sprzedaz.values())
print(suma)
rozne_kwartaly = {kwartal for rok, kwartal in sprzedaz.keys()}
print(len(rozne_kwartaly))
# Out:
# 140,000
# {(2024, 'Q1'): 120000, (2024, 'Q2'): 140000, (2024, 'Q3'): 135000, (2024, 'Q4'): 160000, (2025, 'Q1'): 130000}
# 160000
# 120000
# 685000
# 4

# %%
# Zadanie 9
domyslne = {'lr': 0.01, 'epochs': 100, 'optimizer': 'sgd', 'batch_size': 32}
uzytkownika = {'lr': 0.001, 'batch_size': 64, 'momentum': 0.9}

finalny = domyslne | uzytkownika
print(finalny)
domyslne_copy = domyslne.copy()
domyslne_copy.update(uzytkownika)
print(domyslne_copy)
print(finalny == domyslne_copy)

print(f"lr: {finalny['lr']},\nbatch_size: {finalny['batch_size']},\nmomentum: {finalny['momentum']}")
# Out:
# {'lr': 0.001, 'epochs': 100, 'optimizer': 'sgd', 'batch_size': 64, 'momentum': 0.9}
# {'lr': 0.001, 'epochs': 100, 'optimizer': 'sgd', 'batch_size': 64, 'momentum': 0.9}
# True
# lr: 0.001,
# batch_size: 64,
# momentum: 0.9

# %%
# Zadanie 10
dataset_a = {'wiek', 'plec', 'miasto', 'dochod', 'wyksztalcenie', 'stan_cywilny'}
dataset_b = {'wiek', 'plec', 'miasto', 'pensja', 'stanowisko', 'staz'}

wspolne = dataset_a & dataset_b
print(wspolne)

a_minus_b = dataset_a - dataset_b
print(a_minus_b)

b_minus_a = dataset_b - dataset_a
print(b_minus_a)

unikaty = dataset_a | dataset_b
print(unikaty)

symetryczna = dataset_a ^ dataset_b
print(symetryczna)

wiek_i_plec = {'wiek', 'plec'}
czy_podzbior = wiek_i_plec.issubset(wspolne)
print(czy_podzbior)
# Out:
# {'plec', 'miasto', 'wiek'}
# {'dochod', 'wyksztalcenie', 'stan_cywilny'}
# {'pensja', 'staz', 'stanowisko'}
# {'staz', 'plec', 'miasto', 'wyksztalcenie', 'stan_cywilny', 'pensja', 'stanowisko', 'dochod', 'wiek'}
# {'staz', 'pensja', 'wyksztalcenie', 'stan_cywilny', 'stanowisko', 'dochod'}
# True

# %%
# Zadanie 11
raport = {
'Q1': {'przychod': 120_000, 'koszt': 80_000},
'Q2': {'przychod': 145_000, 'koszt': 92_000},
'Q3': {'przychod': 138_000, 'koszt': 88_000},
'Q4': {'przychod': 167_000, 'koszt': 101_000}
}

print('- '*50)
print(f"Przychody: \nQ1 {raport['Q1']['przychod']} \nQ2 {raport['Q2']['przychod']} \nQ3 {raport['Q3']['przychod']} \nQ4 {raport['Q4']['przychod']}")
print('- '*50)
raport['Q1']['zysk'] = raport['Q1']['przychod'] - raport['Q1']['koszt']
raport['Q2']['zysk'] = raport['Q2']['przychod'] - raport['Q2']['koszt']
raport['Q3']['zysk'] = raport['Q3']['przychod'] - raport['Q3']['koszt']
raport['Q4']['zysk'] = raport['Q4']['przychod'] - raport['Q4']['koszt']

for kwartal, dane in raport.items():
    print(f"{kwartal}: {dane}")

print('- '*50)
print()

print('-'*40)
print(f"KWARTAŁ | PRZYCHÓD |  KOSZT |     ZYSK")
print('-'*40)
print(f"{list(raport.keys())[0]:^7} | {raport['Q1']['przychod']:>8} | {raport['Q1']['koszt']:>6} | {raport['Q1']['zysk']:>8}")
print(f"{list(raport.keys())[1]:^7} | {raport['Q2']['przychod']:>8} | {raport['Q2']['koszt']:>6} | {raport['Q2']['zysk']:>8}")
print(f"{list(raport.keys())[2]:^7} | {raport['Q3']['przychod']:>8} | {raport['Q3']['koszt']:>6} | {raport['Q3']['zysk']:>8}")
print(f"{list(raport.keys())[3]:^7} | {raport['Q4']['przychod']:>8} | {raport['Q4']['koszt']:>6} | {raport['Q4']['zysk']:>8}")

print()

zyski_lista = [raport['Q1']['zysk'], raport['Q2']['zysk'], raport['Q3']['zysk'], raport['Q4']['zysk']]
zyski_sr = sum(zyski_lista) / len(zyski_lista)
zysk_maks = max(zyski_lista)
zysk_min = min(zyski_lista)
zysk_total = sum(zyski_lista)
print(zyski_lista)
print(zyski_sr)
print(zysk_maks)
print(zysk_min)
print(zysk_total)
# Out:
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Przychody:
# Q1 120000
# Q2 145000
# Q3 138000
# Q4 167000
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Q1: {'przychod': 120000, 'koszt': 80000, 'zysk': 40000}
# Q2: {'przychod': 145000, 'koszt': 92000, 'zysk': 53000}
# Q3: {'przychod': 138000, 'koszt': 88000, 'zysk': 50000}
# Q4: {'przychod': 167000, 'koszt': 101000, 'zysk': 66000}
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ----------------------------------------
# KWARTAŁ | PRZYCHÓD |  KOSZT |     ZYSK
# ----------------------------------------
#   Q1    |   120000 |  80000 |    40000
#   Q2    |   145000 |  92000 |    53000
#   Q3    |   138000 |  88000 |    50000
#   Q4    |   167000 | 101000 |    66000
#
# [40000, 53000, 50000, 66000]
# 52250.0
# 66000
# 40000
# 209000

# %%
# Zadanie 12
rekord = ('setosa', 5.1, 3.5, 1.4, 0.2)
gatunek, sl, sw, pl, pw = rekord

rekord_slownik = {
'species': gatunek, 
'sepal_length': sl,
'sepal_width': sw, 
'petal_length': pl, 
'petal_width': pw
}

for klucz, wartosc in rekord_slownik.items():
    if isinstance(wartosc, (int, float)): #isistance nie znałem
        print(f"{klucz:<13} :  {wartosc:>5.1f}")
    else:
        print(f"{klucz:<13} :  {wartosc:>5}")
        
print()
suma_cech_liczbowych = sum(rekord[1:])
print(suma_cech_liczbowych)
# Out:
# species       :  setosa
# sepal_length  :   5.10
# sepal_width   :   3.50
# petal_length  :   1.40
# petal_width   :   0.20
#
# 10.2

# %%
# Zadanie 13
wyniki = {
'LogReg': {'acc': 0.9667, 'prec': 0.9673, 'rec': 0.9667, 'f1': 0.9667},
'DecisionTree': {'acc': 0.9333, 'prec': 0.9342, 'rec': 0.9333, 'f1': 0.9332},
'RandomForest': {'acc': 0.9600, 'prec': 0.9610, 'rec': 0.9600, 'f1': 0.9601}
}
print(wyniki)
print(list(wyniki.values())[0]['acc'])
print()
print('='*60)
print(f"{'Model':<18} {'Acc':<8} {'Prec':<8} {'Rec':<8} {'F1':<8}")
print('='*60)
print(f"{list(wyniki.keys())[0]:<18} {wyniki['LogReg']['acc']:<8.4f} {wyniki['LogReg']['prec']:<8.4f} {wyniki['LogReg']['rec']:<8.4f} {wyniki['LogReg']['f1']:<8.4f}")
print(f"{list(wyniki.keys())[1]:<18} {wyniki['DecisionTree']['acc']:<8.4f} {wyniki['DecisionTree']['prec']:<8.4f} {wyniki['DecisionTree']['rec']:<8.4f} {wyniki['DecisionTree']['f1']:<8.4f}")
print(f"{list(wyniki.keys())[2]:<18} {wyniki['RandomForest']['acc']:<8.4f} {wyniki['RandomForest']['prec']:<8.4f} {wyniki['RandomForest']['rec']:<8.4f} {wyniki['RandomForest']['f1']:<8.4f}")
print('='*60)

srednia_acc = (wyniki['LogReg']['acc'] + wyniki['DecisionTree']['acc'] + wyniki['RandomForest'] ['acc']) / 3

srednia_f1 = (wyniki['LogReg']['f1'] + wyniki['DecisionTree']['f1'] + wyniki['RandomForest'] ['f1']) / 3

print(f"Średnia acc: {srednia_acc:.4f}")
print(f"Średnia f1:  {srednia_f1:.4f}")
# Out:
# {'LogReg': {'acc': 0.9667, 'prec': 0.9673, 'rec': 0.9667, 'f1': 0.9667}, 'DecisionTree': {'acc': 0.9333, 'prec': 0.9342, 'rec': 0.9333, 'f1': 0.9332}, 'RandomForest': {'acc': 0.96, 'prec': 0.961, 'rec': 0.96, 'f1': 0.9601}}
# 0.9667
#
# ...
# Model              Acc      Prec     Rec      F1
# ...
# LogReg             0.9667   0.9673   0.9667   0.9667
# DecisionTree       0.9333   0.9342   0.9333   0.9332
# RandomForest       0.9600   0.9610   0.9600   0.9601
# ...
# Średnia acc: 0.9533
# Średnia f1:  0.9533

# %%
print(f"Model Acc Prec  Rec F1")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29876/3169080460.py in <module>
# ----> 1 print(f)
#
# NameError: name 'f' is not defined

# %%
# Zadanie 14
dane = [
('setosa', 5.1, 3.5, 1.4, 0.2),
('setosa', 4.9, 3.0, 1.4, 0.2),
('versicolor', 7.0, 3.2, 4.7, 1.4),
('versicolor', 6.4, 3.2, 4.5, 1.5),
('virginica', 6.3, 3.3, 6.0, 2.5),
('virginica', 5.8, 2.7, 5.1, 1.9),
('setosa', 4.7, 3.2, 1.3, 0.2)
]
print(dane)

gatunki = {dane[0][0], dane[1][0], dane[2][0], dane[3][0], dane[4][0], dane[5][0], dane[6]
[0]}
print()
print(gatunki)

unikalne_gatunki = len(gatunki)
print(unikalne_gatunki)
print()
pierwszy_rekord = dane[0] 
gatunek, sl, sw, pl, pw = pierwszy_rekord
print(f"{pierwszy_rekord}, {gatunek}, {sl}, {sw}, {pl}, {pw}")
print()
sepal_length = [dane[0][1], dane[1][1], dane[2][1], dane[3][1], dane[4][1], dane[5][1], dane[6][1]]
print(sepal_length)

sepal_length_min = min(sepal_length)
sepal_length_max = max(sepal_length)
sepal_length_srednia = sum(sepal_length) / len(sepal_length)
sepal_length_suma = sum(sepal_length)

print(sepal_length_min)
print(sepal_length_max)
print(f"{sepal_length_srednia:.3f}")
print(sepal_length_suma)
# Out:
# [('setosa', 5.1, 3.5, 1.4, 0.2), ('setosa', 4.9, 3.0, 1.4, 0.2), ('versicolor', 7.0, 3.2, 4.7, 1.4), ('versicolor', 6.4, 3.2, 4.5, 1.5), ('virginica', 6.3, 3.3, 6.0, 2.5), ('virginica', 5.8, 2.7, 5.1, 1.9), ('setosa', 4.7, 3.2, 1.3, 0.2)]
#
# {'versicolor', 'setosa', 'virginica'}
# 3
#
# ('setosa', 5.1, 3.5, 1.4, 0.2), setosa. 5.1, 3.5, 1.4, 0.2
#
# [5.1, 4.9, 7.0, 6.4, 6.3, 5.8, 4.7]
# 4.7
# 7.0
# 5.743
# 40.2

# %%
# Zadanie 16
sprzedaz = {
(2024, 'Q1'): 120_000,
(2024, 'Q2'): 145_000,
(2024, 'Q3'): 138_000,
(2024, 'Q4'): 167_000,
(2025, 'Q1'): 130_000,
(2025, 'Q2'): 155_000,
(2025, 'Q3'): 149_000
}
print(sprzedaz)
calkowita_sprzedaz = sum(sprzedaz.values())
max_sprzedaz = max(sprzedaz.values())
min_sprzedaz = min(sprzedaz.values())
klucz_max = max(sprzedaz, key=sprzedaz.get)

print(klucz_max)
print(calkowita_sprzedaz)
print(max_sprzedaz)
print(min_sprzedaz)
# Out:
# {(2024, 'Q1'): 120000, (2024, 'Q2'): 145000, (2024, 'Q3'): 138000, (2024, 'Q4'): 167000, (2025, 'Q1'): 130000, (2025, 'Q2'): 155000, (2025, 'Q3'): 149000}
# (2024, 'Q4')
# 1004000
# 167000
# 120000

# %%
# Zadanie 18
projekt = {
    'nazwa': 'iris_classification',
    'wersja': (1, 2, 0), # krotka – wersja jako (major, minor,patch)
    'autorzy': {'Anna', 'Bartek', 'Cezary'}, # zbiór
    'dataset': {
        'nazwa': 'Iris',
        'shape': (150, 4),
        'klasy': ('setosa', 'versicolor', 'virginica')
    },
    'hiperparametry': {
        'lr': 0.001,
        'batch_size': 64,
        'epochs': 50
    }
}
print(projekt)


major, minor, patch = projekt['wersja']
print(f"v{major}.{minor}.{patch}")
print()
n_rekordow, n_cech = projekt['dataset']['shape']
print(f"Dataset {projekt['dataset']['nazwa']}: {n_rekordow} x {n_cech}")
print()
projekt['autorzy'].add('Dorota')
print(f"Liczba autorów: {len(projekt['autorzy'])}")
autorzy_sort = sorted(projekt['autorzy'])
print(autorzy_sort)
print()
hiperparametry_update_slownika = {'dropout': 0.3, 'batch_size': 128}
projekt['hiperparametry'].update(hiperparametry_update_slownika)
print(projekt['hiperparametry'])
print()
projekt['dataset']['klasy'] = set(projekt['dataset']['klasy'])
czy_w_zbiorze ='setosa' in projekt['dataset']['klasy']
print(f"Czy setosa jest w zbiorze? {czy_w_zbiorze}")
# Out:
# {'nazwa': 'iris_classification', 'wersja': (1, 2, 0), 'autorzy': {'Cezary', 'Bartek', 'Anna'}, 'dataset': {'nazwa': 'Iris', 'shape': (150, 4), 'klasy': ('setosa', 'versicolor', 'virginica')}, 'hiperparametry': {'lr': 0.001, 'batch_size': 64, 'epochs': 50}}
# v1.2.0
#
# Dataset Iris: 150 x 4
#
# Liczba autorów: 4
# ['Anna', 'Bartek', 'Cezary', 'Dorota']
#
# {'lr': 0.001, 'batch_size': 128, 'epochs': 50, 'dropout': 0.3}
#
# Czy setosa jest w zbiorze? True

# %%
# Zadanie 17
wersja_1 = {'lr': 0.01, 'epochs': 100, 'optimizer': 'sgd', 'batch_size': 32, 'dropout': 0.2}
wersja_2 = {'lr': 0.001, 'epochs': 100, 'optimizer': 'adam', 'batch_size': 64, 'momentum': 0.9}

klucze_wersja_1 = set(wersja_1.keys())
print(klucze_wersja_1)
klucze_wersja_2 = set(wersja_2.keys())
print(klucze_wersja_2)
print()
unikaty_1_2 = klucze_wersja_1 | klucze_wersja_2
print(unikaty_1_2)
print()
wspolne_1_2 = klucze_wersja_1 & klucze_wersja_2
print(wspolne_1_2)
print()
klucze_tylko_1 = klucze_wersja_1 - klucze_wersja_2
print(klucze_tylko_1)
klucze_tylko_2 = klucze_wersja_2 - klucze_wersja_1
print(klucze_tylko_2)
# Out:
# {'epochs', 'dropout', 'optimizer', 'batch_size', 'lr'}
# {'epochs', 'optimizer', 'momentum', 'batch_size', 'lr'}
#
# {'epochs', 'dropout', 'optimizer', 'momentum', 'batch_size', 'lr'}
#
# {'epochs', 'batch_size', 'optimizer', 'lr'}
#
# {'dropout'}
# {'momentum'}

# %%
# Zadanie 15
